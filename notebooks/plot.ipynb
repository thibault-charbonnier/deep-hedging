# %%
from src.utils.run_plots import plot_run

# %%
plot_run("20260423_100651_GBM_DeepDPG_BsDelta_0b5368")
# Out:
# Run utilise: 20260423_100651_GBM_DeepDPG_BsDelta_0b5368
# Improvement RL vs Benchmark = 16.13%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        80.874831       40.807472         0.395852   142.086039
# 1     Benchmark       107.689075       41.144729         0.585871   169.406168
# Skewness Analysis:
#   RL Agent skewness:      0.3959
#   Benchmark skewness:     0.5859
#   Difference (RL-BM):    -0.1900
