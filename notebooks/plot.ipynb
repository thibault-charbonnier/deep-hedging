# %%
from src.utils.run_plots import plot_all_graphs

# %%
plot_all_graphs("20260422_225610_SVJ_DeepDPG_BsDelta_5c6207")
# Out:
# Run utilise: 20260422_225610_SVJ_DeepDPG_BsDelta_5c6207
# Improvement RL vs Benchmark = 16.29%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        78.935361       47.865514         0.436108   150.733631
# 1     Benchmark       108.488866       47.720045         1.266633   180.068934
# Skewness Analysis:
#   RL Agent skewness:      0.4361
#   Benchmark skewness:     1.2666
#   Difference (RL-BM):    -0.8305

# %%
plot_all_graphs("20260422_225652_GBM_DeepDPG_BsDelta_e499fe")
# Out:
# Run utilise: 20260422_225652_GBM_DeepDPG_BsDelta_e499fe
# Improvement RL vs Benchmark = 11.50%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        80.384502       43.387275         0.007869   145.465413
# 1     Benchmark       107.539623       37.887878         0.508260   164.371440
# Skewness Analysis:
#   RL Agent skewness:      0.0079
#   Benchmark skewness:     0.5083
#   Difference (RL-BM):    -0.5004

# %%
plot_all_graphs("20260422_230657_GBM_DeepDPG_BsDelta_0dfc20")
# Out:
# Run utilise: 20260422_230657_GBM_DeepDPG_BsDelta_0dfc20
# Improvement RL vs Benchmark = 13.97%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        95.514487       45.273426         0.106072   163.424626
# 1     Benchmark       129.517138       40.297580         0.614954   189.963508
# Skewness Analysis:
#   RL Agent skewness:      0.1061
#   Benchmark skewness:     0.6150
#   Difference (RL-BM):    -0.5089

# %%
plot_all_graphs("20260422_230832_GBM_DeepDPG_BsDelta_258c7c")
# Out:
# Run utilise: 20260422_230832_GBM_DeepDPG_BsDelta_258c7c
# Improvement RL vs Benchmark = 11.40%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        85.069829       42.376532         0.113691   148.634628
# 1     Benchmark       107.306085       40.297580         0.614954   167.752455
# Skewness Analysis:
#   RL Agent skewness:      0.1137
#   Benchmark skewness:     0.6150
#   Difference (RL-BM):    -0.5013

# %%
plot_all_graphs("20260422_231203_GBM_DeepDPG_BsDelta_217b4c")
# Out:
# Run utilise: 20260422_231203_GBM_DeepDPG_BsDelta_217b4c
# Improvement RL vs Benchmark = 11.56%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        76.872848       47.661234         0.209492   148.364699
# 1     Benchmark       107.306084       40.297580         0.614954   167.752454
# Skewness Analysis:
#   RL Agent skewness:      0.2095
#   Benchmark skewness:     0.6150
#   Difference (RL-BM):    -0.4055
