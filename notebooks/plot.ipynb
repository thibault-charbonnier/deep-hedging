# %%
from src.utils.run_plots import plot_all_graphs

# %%
plot_all_graphs("20260422_235540_GBM_DeepDPG_BsDelta_de6b34")
# Out:
# Run utilise: 20260422_235540_GBM_DeepDPG_BsDelta_de6b34
# Improvement RL vs Benchmark = 18.37%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        48.828301       47.360378         0.698839   119.868868
# 1     Benchmark        85.064870       41.184619         0.839645   146.841799
# Skewness Analysis:
#   RL Agent skewness:      0.6988
#   Benchmark skewness:     0.8396
#   Difference (RL-BM):    -0.1408
