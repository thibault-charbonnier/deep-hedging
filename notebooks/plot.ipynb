# %%
from src.utils.run_plots import plot_all_graphs

# %%
plot_all_graphs("20260421_094708_GBM_DeepDPG_BsDelta_f012d7")

# %%
plot_all_graphs("20260421_095504_GBM_DeepDPG_BsDelta_ec59a5")

# %%
plot_all_graphs("20260421_100245_GBM_DeepDPG_BsDelta_b90951")

# %%
plot_all_graphs("20260421_101034_GBM_DeepDPG_BsDelta_7a6bc6")

# %%
plot_all_graphs("20260421_105439_GBM_DeepDPG_BsDelta_e40691")

# %%
plot_all_graphs("20260421_112110_GBM_DeepDPG_BsDelta_060aac")

# %%
plot_all_graphs("20260421_113007_GBM_DeepDPG_BsDelta_b84ef2")

# %%
plot_all_graphs("20260421_113904_GBM_DeepDPG_BsDelta_ad5a9f")

# %%
plot_all_graphs("20260421_114814_GBM_DeepDPG_BsDelta_15dc65")

# %%
plot_all_graphs("20260421_120600_GBM_DeepDPG_BsDelta_76e9b2")

# %%
plot_all_graphs("20260421_122350_GBM_DeepDPG_BsDelta_18abba")

# %%
plot_all_graphs("20260421_124136_GBM_DeepDPG_BsDelta_ec5a56")

# %%
plot_all_graphs("20260421_131712_GBM_DeepDPG_BsDelta_7fd3b4")

# %%
plot_all_graphs("20260421_135237_GBM_DeepDPG_BsDelta_74fe9a")

# %%
plot_all_graphs("20260421_142731_GBM_DeepDPG_BsDelta_1c382e")

# %%
plot_all_graphs("20260421_145914_GBM_DeepDPG_BsDelta_4015e6")

# %%
plot_all_graphs("20260421_172414_GBM_DeepDPG_BsDelta_7ebe8d")
# Out:
# Run utilise: 20260421_172414_GBM_DeepDPG_BsDelta_7ebe8d
# Improvement RL vs Benchmark = -65.87%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        76.798818      130.919734         1.676857   273.178419
# 1     Benchmark       108.557320       37.424421         0.458713   164.693951
# Skewness Analysis:
#   RL Agent skewness:      1.6769
#   Benchmark skewness:     0.4587
#   Difference (RL-BM):     1.2181

# %%
plot_all_graphs("20260421_173037_GBM_DeepDPG_BsDelta_add8da")
# Out:
# Run utilise: 20260421_173037_GBM_DeepDPG_BsDelta_add8da
# Improvement RL vs Benchmark = -120.46%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        93.868040      177.811602         1.375911   360.585443
# 1     Benchmark       106.988187       37.715169         0.455976   163.560940
# Skewness Analysis:
#   RL Agent skewness:      1.3759
#   Benchmark skewness:     0.4560
#   Difference (RL-BM):     0.9199

# %%
plot_all_graphs("20260421_180042_GBM_DeepDPG_BsDelta_45d64c")
# Out:
# Run utilise: 20260421_180042_GBM_DeepDPG_BsDelta_45d64c
# Improvement RL vs Benchmark = -4.59%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        74.114964       65.427692         1.232325   172.256502
# 1     Benchmark       108.557320       37.424421         0.458713   164.693951
# Skewness Analysis:
#   RL Agent skewness:      1.2323
#   Benchmark skewness:     0.4587
#   Difference (RL-BM):     0.7736

# %%
plot_all_graphs("20260421_180745_GBM_DeepDPG_BsDelta_76f9d2")
# Out:
# Run utilise: 20260421_180745_GBM_DeepDPG_BsDelta_76f9d2
# Improvement RL vs Benchmark = -0.44%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        67.096736       65.545146         0.700442   165.414455
# 1     Benchmark       108.557320       37.424421         0.458713   164.693951
# Skewness Analysis:
#   RL Agent skewness:      0.7004
#   Benchmark skewness:     0.4587
#   Difference (RL-BM):     0.2417
