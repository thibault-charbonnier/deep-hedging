# %%
from src.utils.run_plots import plot_all_graphs

# %%
plot_all_graphs("20260423_001544_GBM_DeepDPG_BsDelta_d45a86")
# Out:
# Run utilise: 20260423_001544_GBM_DeepDPG_BsDelta_d45a86
# Improvement RL vs Benchmark = 13.22%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        78.609047       45.604005         0.405188   147.015054
# 1     Benchmark       107.689075       41.144729         0.585871   169.406168
# Skewness Analysis:
#   RL Agent skewness:      0.4052
#   Benchmark skewness:     0.5859
#   Difference (RL-BM):    -0.1807
