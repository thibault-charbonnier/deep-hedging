# %%
from src.utils.run_plots import plot_all_graphs

# %%
plot_all_graphs("20260422_232449_GBM_DeepDPG_BsDelta_2a6931")
# Out:
# Run utilise: 20260422_232449_GBM_DeepDPG_BsDelta_2a6931
# Improvement RL vs Benchmark = 16.39%
#          method  mean_total_cost  std_total_cost  skew_total_cost  y_objective
# 0  RL (DeepDPG)        64.366005       50.585656         0.778210   140.244489
# 1     Benchmark       106.409374       40.886624         0.707378   167.739310
# Skewness Analysis:
#   RL Agent skewness:      0.7782
#   Benchmark skewness:     0.7074
#   Difference (RL-BM):     0.0708
