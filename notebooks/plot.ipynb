# %%
from src.utils.run_plots import plot_run

# %%
plot_run("20260423_155334_SVJ_DeepDPG_BsDelta_acd23e",include_skew_in_y=True)

# %%
plot_run("20260423_155741_SVJ_SkewDDPG_BsDelta_bdc57f",include_skew_in_y=True)

# %%
plot_run("20260423_162811_SVJ_SkewDDPG_BsDelta_def193",include_skew_in_y=True)

# %%
plot_run("20260423_163450_SVJ_SkewDDPG_BsDelta_928d1b",include_skew_in_y=True)

# %%
plot_run("20260423_164539_SVJ_SkewDDPG_BsDelta_0b341d",include_skew_in_y=True)

# %%
plot_run("20260423_170808_SVJ_DeepDPG_BsDelta_43a236",include_skew_in_y=True)

# %%
plot_run("20260423_180544_GBM_QRDDPG_BsDelta_3b97cc",include_skew_in_y=True)
